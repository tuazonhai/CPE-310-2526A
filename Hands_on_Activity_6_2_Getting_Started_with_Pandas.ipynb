# %% [markdown]
# <a href="https://colab.research.google.com/github/tuazonhai/CPE-310-2526A/blob/main/Hands_on_Activity_6_2_Getting_Started_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EXERCISES**

# %% [markdown]
# **EXERCISES - 2019_Yellow_Taxi_Trip_Data**

# %%
# Exercise 1.1 Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.
import pandas as pd
taxi_df = pd.read_csv("/2019_Yellow_Taxi_Trip_Data(1)(1).csv")

taxi_df.head()
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %%
# Exercise 1.2 Find the dimensions (number of rows and number of columns) in the data.

taxi_df.shape
# Out:
# (10000, 18)

# %%
# Exercise 1.3 Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns.

taxi_df[["fare_amount", "tip_amount", "tolls_amount", "total_amount"]].describe()
# Out:
#         fare_amount    tip_amount  tolls_amount  total_amount
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      15.106313      2.634494      0.623447     22.564659
# std       13.954762      3.409800      6.437507     19.209255
# min      -52.000000      0.000000     -6.120000    -65.920000
# 25%        7.000000      0.000000      0.000000     12.375000
# 50%       10.000000      2.000000      0.000000     16.300000
# 75%       16.000000      3.250000      0.000000     22.880000
# max      176.000000     43.000000    612.000000    671.800000

# %%
# Exercise 1.4 Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

taxi_df.loc[taxi_df["trip_distance"].idxmax(), ['fare_amount', 'tip_amount', "tolls_amount", 'total_amount']]
# Out:
# fare_amount      176.0
# tip_amount       18.29
# tolls_amount      6.12
# total_amount    201.21
# Name: 8338, dtype: object

# %% [markdown]
# **SUPPLEMENTARY ACTIVITY - AUTOMOBILE**

# %%
# Exercise 1.1 Create a DataFrame by reading in the 21985 Auto Imports - Excel Data Export_ 1985 Auto Imports.csv file. Examine the first 5 rows.

import pandas as pd
auto_imports = pd.read_csv("/Excel Data Export_ 1985 Auto Imports - Excel Data Export_ 1985 Auto Imports.csv")

auto_imports.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Exercise 1.2 Find the dimensions (number of rows and number of columns) in the data.

auto_imports.shape
# Out:
# (14, 26)

# %%
# Exercise 1.3 Using the data in the 1985 Auto Imports - Excel Data Export_ 1985 Auto Imports.csv file, calculate summary statistics.

auto_imports.describe(include = "all")
# Out:
#         symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# count   14.000000                14    14        14         14           14
# unique        NaN                 5     3         1          2            2
# top           NaN                 ?  audi       gas        std          two
# freq          NaN                 6     7        14         12            7
# mean     1.285714               NaN   NaN       NaN        NaN          NaN
# std      1.069045               NaN   NaN       NaN        NaN          NaN
# min      0.000000               NaN   NaN       NaN        NaN          NaN
# 25%      0.250000               NaN   NaN       NaN        NaN          NaN
# 50%      1.000000               NaN   NaN       NaN        NaN          NaN
# 75%      2.000000               NaN   NaN       NaN        NaN          NaN
# max      3.000000               NaN   NaN       NaN        NaN          NaN
#
# ...

# %%
# Exercise 1.4 Isolate the make, engine-size, horsepower, city-mpg, highway-mpg, and price.

auto_imports.loc[auto_imports['price'].idxmax(), ['make', 'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price']]
# Out:
# make           audi
# engine-size     131
# horsepower      160
# city-mpg         16
# highway-mpg      22
# price             ?
# Name: 9, dtype: object
